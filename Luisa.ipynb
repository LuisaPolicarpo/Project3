# %% [markdown]
# <a href="https://colab.research.google.com/github/LuisaPolicarpo/Project3/blob/main/Luisa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
name_basics = pd.read_csv(r'/content/drive/MyDrive/Project 3/name.basics.tsv.gz',compression= "gzip",sep='\t') 
name_basics

# primaryName, primaryProfession, KnowForTitles, nconst(conect with title principals)- L
# Out:
#              nconst         primaryName birthYear deathYear  \
# 0         nm0000001        Fred Astaire      1899      1987
# 1         nm0000002       Lauren Bacall      1924      2014
# 2         nm0000003     Brigitte Bardot      1934        \N
# 3         nm0000004        John Belushi      1949      1982
# 4         nm0000005      Ingmar Bergman      1918      2007
# ...             ...                 ...       ...       ...
# 12005700  nm9993714   Romeo del Rosario        \N        \N
# 12005701  nm9993716       Essias Loberg        \N        \N
# 12005702  nm9993717  Harikrishnan Rajan        \N        \N
# 12005703  nm9993718         Aayush Nair        \N        \N
# 12005704  nm9993719          Andre Hill        \N        \N
#
#                             primaryProfession  \
# 0              soundtrack,actor,miscellaneous
# 1                          actress,soundtrack
# 2         actress,soundtrack,music_department
# 3                     actor,soundtrack,writer
# ...

# %%
title_akas = pd.read_csv(r'/content/drive/MyDrive/Project 3/title.akas.tsv.gz',compression= "gzip",sep='\t') 
title_akas

#TitleId, title, region, language (check), types and attributes (check), isoriginaltitle
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#             titleId  ordering                      title region language  \
# 0         tt0000001         1                 Карменсіта     UA       \N
# 1         tt0000001         2                 Carmencita     DE       \N
# 2         tt0000001         3  Carmencita - spanyol tánc     HU       \N
# 3         tt0000001         4                 Καρμενσίτα     GR       \N
# 4         tt0000001         5                 Карменсита     RU       \N
# ...             ...       ...                        ...    ...      ...
# 33503602  tt9916852         5             Episódio #3.20     PT       pt
# 33503603  tt9916852         6             Episodio #3.20     IT       it
# 33503604  tt9916852         7               एपिसोड #3.20     IN       hi
# ...

# %%
title_basics = pd.read_csv(r'/content/drive/MyDrive/Project 3/title.basics.tsv.gz',compression= "gzip",sep='\t') 
title_basics
# tconst, titleType, (primaryTitle= originaltitle (?)) check, isAdult, staryear, endyear (check) -M
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#             tconst  titleType               primaryTitle  \
# 0        tt0000001      short                 Carmencita
# 1        tt0000002      short     Le clown et ses chiens
# 2        tt0000003      short             Pauvre Pierrot
# 3        tt0000004      short                Un bon bock
# 4        tt0000005      short           Blacksmith Scene
# ...            ...        ...                        ...
# 9301897  tt9916848  tvEpisode              Episode #3.17
# 9301898  tt9916850  tvEpisode              Episode #3.19
# 9301899  tt9916852  tvEpisode              Episode #3.20
# 9301900  tt9916856      short                   The Wind
# 9301901  tt9916880  tvEpisode  Horrid Henry Knows It All
#
# ...

# %%
title_crew = pd.read_csv(r'/content/drive/MyDrive/Project 3/title.crew.tsv.gz',compression= "gzip",sep='\t') 
title_crew

#all- M
# Out:
#             tconst            directors                        writers
# 0        tt0000001            nm0005690                             \N
# 1        tt0000002            nm0721526                             \N
# 2        tt0000003            nm0721526                             \N
# 3        tt0000004            nm0721526                             \N
# 4        tt0000005            nm0005690                             \N
# ...            ...                  ...                            ...
# 9301897  tt9916848  nm5519454,nm5519375  nm6182221,nm1628284,nm2921377
# 9301898  tt9916850  nm5519454,nm5519375  nm6182221,nm1628284,nm2921377
# 9301899  tt9916852  nm5519454,nm5519375  nm6182221,nm1628284,nm2921377
# 9301900  tt9916856           nm10538645                      nm6951431
# 9301901  tt9916880            nm0996406            nm1482639,nm2586970
#
# [9301902 rows x 3 columns]

# %%
title_epi = pd.read_csv(r'/content/drive/MyDrive/Project 3/title.episode.tsv.gz',compression= "gzip",sep='\t') 
title_epi
#all -F
# Out:
#             tconst parentTconst seasonNumber episodeNumber
# 0        tt0020666   tt15180956            1             2
# 1        tt0020829   tt15180956            1             1
# 2        tt0021166   tt15180956            1             3
# 3        tt0021612   tt15180956            2             2
# 4        tt0021655   tt15180956            2             5
# ...            ...          ...          ...           ...
# 7017990  tt9916846    tt1289683            3            18
# 7017991  tt9916848    tt1289683            3            17
# 7017992  tt9916850    tt1289683            3            19
# 7017993  tt9916852    tt1289683            3            20
# 7017994  tt9916880    tt0985991            4             2
#
# [7017995 rows x 4 columns]

# %%
title_pri= pd.read_csv(r'/content/drive/MyDrive/Project 3/title.principals.tsv.gz',compression= "gzip",sep='\t')
title_pri
#tconst, nconst	, category, job (check)- L
# Out:
#              tconst  ordering      nconst         category  \
# 0         tt0000001         1   nm1588970             self
# 1         tt0000001         2   nm0005690         director
# 2         tt0000001         3   nm0374658  cinematographer
# 3         tt0000002         1   nm0721526         director
# 4         tt0000002         2   nm1335271         composer
# ...             ...       ...         ...              ...
# 52588459  tt9916880         4  nm10535738          actress
# 52588460  tt9916880         5   nm0996406         director
# 52588461  tt9916880         6   nm1482639           writer
# 52588462  tt9916880         7   nm2586970           writer
# 52588463  tt9916880         8   nm1594058         producer
#
#                               job        characters
# 0                              \N          ["Self"]
# 1                              \N                \N
# 2         director of photography                \N
# ...

# %%
title_rat= pd.read_csv(r'/content/drive/MyDrive/Project 3/title.ratings.tsv.gz',compression= "gzip",sep='\t')
title_rat
#all- F
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.7      1919
# 1        tt0000002            5.8       260
# 2        tt0000003            6.5      1727
# 3        tt0000004            5.6       173
# 4        tt0000005            6.2      2541
# ...            ...            ...       ...
# 1238667  tt9916690            7.4         6
# 1238668  tt9916720            5.3       267
# 1238669  tt9916730            8.4         6
# 1238670  tt9916766            6.7        21
# 1238671  tt9916778            7.3        35
#
# [1238672 rows x 3 columns]
